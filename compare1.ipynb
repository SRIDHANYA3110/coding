# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
SR=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")

# %%
SR
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
SR.shape
# Out:
# (500, 9)

# %%
SR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
nd=SR.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
nd
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 495        332              0.87
# 496        337              0.96
# 497        330              0.93
# 498        312              0.73
# 499        327              0.84
#
# [500 rows x 2 columns]

# %%
x=nd.iloc[:,0].values.reshape(-1,1)

# %%
y=nd.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel("GRE SCORE")
pt.ylabel('CHANCE')
pt.title("linear regression")
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import  LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_prediction=lm.predict(X_test)

# %%
y_prediction
# Out:
# array([[0.74266191],
#        [0.77455946],
#        [0.77455946],
#        [0.84898706],
#        [0.56190917],
#        [0.70013186],
#        [0.53001162],
#        [0.57254168],
#        [0.51937911],
#        [0.806457  ],
#        [0.7320294 ],
#        [0.76392694],
#        [0.70013186],
#        [0.68949934],
#        [0.91278215],
#        [0.51937911],
#        [0.79582449],
#        [0.7320294 ],
#        [0.82772203],
#        [0.55127665],
#        [0.49811408],
#        [0.76392694],
#        [0.50874659],
#        [0.8808846 ],
#        [0.78519197],
#        [0.74266191],
#        [0.81708952],
#        [0.66823431],
#        [0.61507174],
#        [0.59380671],
#        [0.72139688],
#        [0.50874659],
#        [0.56190917],
#        [0.79582449],
#        [0.71076437],
#        [0.53001162],
#        [0.84898706],
#        [0.806457  ],
#        [0.55127665],
#        [0.6576018 ],
#        [0.70013186],
#        [0.85961957],
#        [0.87025209],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['GRE'])

# %%
COMP
# Out:
#      GRE
# 0    318
# 1    321
# 2    321
# 3    328
# 4    301
# ..   ...
# 245  317
# 246  297
# 247  312
# 248  323
# 249  340
#
# [250 rows x 1 columns]

# %%
COMP['CHA']=Y_test

# %%
COMP
# Out:
#      GRE   CHA
# 0    318  0.64
# 1    321  0.85
# 2    321  0.80
# 3    328  0.91
# 4    301  0.68
# ..   ...   ...
# 245  317  0.77
# 246  297  0.59
# 247  312  0.69
# 248  323  0.79
# 249  340  0.90
#
# [250 rows x 2 columns]

# %%
COMP['PRDDATA']=y_prediction

# %%
COMP
# Out:
#      GRE   CHA   PRDDATA
# 0    318  0.64  0.742662
# 1    321  0.85  0.774559
# 2    321  0.80  0.774559
# 3    328  0.91  0.848987
# 4    301  0.68  0.561909
# ..   ...   ...       ...
# 245  317  0.77  0.732029
# 246  297  0.59  0.519379
# 247  312  0.69  0.678867
# 248  323  0.79  0.795824
# 249  340  0.90  0.976577
#
# [250 rows x 3 columns]

# %%
COMP['AVLDATA']=Y_test

# %% [markdown]
# COMP

# %%
COMP
# Out:
#      GRE   CHA   PRDDATA  AVLDATA
# 0    318  0.64  0.742662     0.64
# 1    321  0.85  0.774559     0.85
# 2    321  0.80  0.774559     0.80
# 3    328  0.91  0.848987     0.91
# 4    301  0.68  0.561909     0.68
# ..   ...   ...       ...      ...
# 245  317  0.77  0.732029     0.77
# 246  297  0.59  0.519379     0.59
# 247  312  0.69  0.678867     0.69
# 248  323  0.79  0.795824     0.79
# 249  340  0.90  0.976577     0.90
#
# [250 rows x 4 columns]

# %%
nd=SR.drop(['Serial No.','GRE Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
nd
# Out:
#      TOEFL Score  Chance of Admit
# 0            118              0.92
# 1            107              0.76
# 2            104              0.72
# 3            110              0.80
# 4            103              0.65
# ..           ...               ...
# 495          108              0.87
# 496          117              0.96
# 497          120              0.93
# 498          103              0.73
# 499          113              0.84
#
# [500 rows x 2 columns]

# %%
x=nd.iloc[:,0].values.reshape(-1,1)

# %%
y=nd.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[118],
#        [107],
#        [104],
#        [110],
#        [103],
#        [115],
#        [109],
#        [101],
#        [102],
#        [108],
#        [106],
#        [111],
#        [112],
#        [109],
#        [104],
#        [105],
#        [107],
#        [106],
#        [110],
#        [102],
#        [107],
#        [114],
#        [116],
#        [119],
#        [119],
#        [120],
#        [109],
#        [ 98],
#        [ 93],
#        [ 99],
#        [ 97],
#        [103],
#        [118],
#        [114],
#        [112],
#        [110],
#        [106],
#        [105],
#        [105],
#        [108],
#        [110],
#        [105],
#        [107],
#        [117],
#        [113],
#        [110],
#        [114],
#        [119],
#        [110],
#        [111],
#        [ 98],
#        [100],
#        [116],
#        [112],
#        [110],
#        [103],
#        [102],
#        [ 99],
#        [ 99],
#        [104],
#        [100],
#        [101],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel("GRE SCORE")
pt.ylabel('CHANCE')
pt.title("linear regression")
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import  LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_prediction=lm.predict(X_test)

# %%
y_prediction
# Out:
# array([[0.70291939],
#        [0.85087303],
#        [0.79539041],
#        [0.88786144],
#        [0.62894257],
#        [0.68442518],
#        [0.61044836],
#        [0.77689621],
#        [0.59195416],
#        [0.68442518],
#        [0.64743677],
#        [0.66593098],
#        [0.62894257],
#        [0.758402  ],
#        [0.90635565],
#        [0.51797733],
#        [0.77689621],
#        [0.70291939],
#        [0.7399078 ],
#        [0.68442518],
#        [0.57345995],
#        [0.66593098],
#        [0.61044836],
#        [0.88786144],
#        [0.77689621],
#        [0.77689621],
#        [0.85087303],
#        [0.55496575],
#        [0.59195416],
#        [0.59195416],
#        [0.64743677],
#        [0.57345995],
#        [0.70291939],
#        [0.77689621],
#        [0.68442518],
#        [0.61044836],
#        [0.7399078 ],
#        [0.83237882],
#        [0.62894257],
#        [0.66593098],
#        [0.72141359],
#        [0.85087303],
#        [0.88786144],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['TOFEL'])

# %%
COMP
# Out:
#      TOFEL
# 0      106
# 1      114
# 2      111
# 3      116
# 4      102
# ..     ...
# 245    104
# 246     98
# 247    107
# 248    112
# 249    114
#
# [250 rows x 1 columns]

# %%
COMP['CHA']=Y_test

# %%
COMP
# Out:
#      TOFEL   CHA
# 0      106  0.64
# 1      114  0.85
# 2      111  0.80
# 3      116  0.91
# 4      102  0.68
# ..     ...   ...
# 245    104  0.77
# 246     98  0.59
# 247    107  0.69
# 248    112  0.79
# 249    114  0.90
#
# [250 rows x 2 columns]

# %%
COMP['PRDDATA']=y_prediction

# %%
COMP
# Out:
#      TOFEL   CHA   PRDDATA
# 0      106  0.64  0.702919
# 1      114  0.85  0.850873
# 2      111  0.80  0.795390
# 3      116  0.91  0.887861
# 4      102  0.68  0.628943
# ..     ...   ...       ...
# 245    104  0.77  0.665931
# 246     98  0.59  0.554966
# 247    107  0.69  0.721414
# 248    112  0.79  0.813885
# 249    114  0.90  0.850873
#
# [250 rows x 3 columns]

# %%
COMP['AVLDATA']=Y_test

# %%
COMP
# Out:
#      TOFEL   CHA   PRDDATA  AVLDATA
# 0      106  0.64  0.702919     0.64
# 1      114  0.85  0.850873     0.85
# 2      111  0.80  0.795390     0.80
# 3      116  0.91  0.887861     0.91
# 4      102  0.68  0.628943     0.68
# ..     ...   ...       ...      ...
# 245    104  0.77  0.665931     0.77
# 246     98  0.59  0.554966     0.59
# 247    107  0.69  0.721414     0.69
# 248    112  0.79  0.813885     0.79
# 249    114  0.90  0.850873     0.90
#
# [250 rows x 4 columns]

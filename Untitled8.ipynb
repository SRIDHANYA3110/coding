# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\admin\.conda\envs\sri\lib\site-packages (3.6.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\sri\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# %matplotlib inline

# %%
movies=['JL','BATMAN','IRONMAN','MASK','AVENGERS']
percentage=[10,20,30,40,50]

# %%
plt.scatter(movies,percentage)

# %%
plt.plot(movies,percentage,linestyle='dashdot')

# %%
plt.plot(movies,percentage,linestyle='dotted')

# %%
plt.pie(percentage,labels=movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bd521c2230>,
#   <matplotlib.patches.Wedge at 0x1bd521c26b0>,
#   <matplotlib.patches.Wedge at 0x1bd521c2b30>,
#   <matplotlib.patches.Wedge at 0x1bd52180f10>,
#   <matplotlib.patches.Wedge at 0x1bd52117eb0>],
#  [Text(1.075962358309037, 0.22870287165240302, 'JL'),
#   Text(0.7360436312779136, 0.817459340184711, 'BATMAN'),
#   Text(-0.33991877217145816, 1.046162142464278, 'IRONMAN'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'MASK'),
#   Text(0.5500001932481627, -0.9526278325909777, 'AVENGERS')])

# %%
plt.bar(movies,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        -0.70554033, -0.66923986, -0.63126664, -0.59171558, -0.55068554,
#        -0.50827908, -0.46460218, -0.41976402, -0.37387666, -0.32705481,
#        -0.2794155 , -0.23107779, -0.1821625 , -0.13279191, -0.0830894 ,
#        -0.03317922,  0.0168139 ,  0.06676499,  0.1165492 ,  0.16604211,
#         0.21511999,  0.26366018,  0.31154136,  0.35864385,  0.40484992,
#         0.45004407,  0.49411335,  0.5369476 ,  0.57843976,  0.61848613,
#         0.6569866 ,  0.69384494,  0.72896904,  0.76227109,  0.79366786,
#         0.82308088,  0.85043662,  0.87566671,  0.8987081 ,  0.91950318,
#         0.93799998,  0.95415227,  0.96791967,  0.97926778,  0.98816823,
#         0.99459878,  0.99854335,  0.99999207,  0.99894134,  0.99539378,
#         0.98935825,  0.98084984,  0.96988981,  0.95650557,  0.94073056,
#         0.92260421,  0.90217183,  0.8794845 ,  0.85459891,  0.82757727,
#         0.79848711,  0.76740116,  0.7343971 ,  0.69955743,  0.66296923,
#         0.62472395,  0.58491719,  0.54364844,  0.50102086,  0.45714098,
#         0.41211849,  0.36606591,  0.31909836,  0.27133323,  0.22288991,
#         0.17388949,  0.12445442,  0.07470829,  0.02477543, -0.02521937,
#        -0.07515112, -0.12489504, -0.17432678, -0.2233228 , -0.27176063,
#        -0.31951919, -0.36647913, -0.41252306, -0.45753589, -0.50140513])

# %%
plt.plot(time,amplitude)

# %%
 pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      -------------------------------------- 288.2/288.2 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\admin\.conda\envs\sri\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\.conda\envs\sri\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\.conda\envs\sri\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\.conda\envs\sri\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\sri\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sb

# %%
sb.set(style='darkgrid')

# %%
random=np.random.randn(100)

# %%
sb.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7032\993580589.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic=sb.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
shree=sb.load_dataset('tips')

# %%
shree
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.relplot(x='total_bill',y='tip',data=shree,col="time",hue="day",style="day",kind="line")

# %%
sb.catplot(x='day',y='total_bill',kind='box',data=shree)

# %%
sb.regplot(x='total_bill',y='tip',data=shree)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>
